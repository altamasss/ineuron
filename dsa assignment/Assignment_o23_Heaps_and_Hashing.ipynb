# %% [markdown]
# # Assignment 23 - Heaps and Hashing

# %% [markdown]
# ![Screenshot 2023-07-02 103133.png](data:image/png;base64,...)

# %%
def find_depth_tool(tree,n,index) :

    if (index[0] >= n or tree[index[0]] == 'l'):
        return 0

    index[0] += 1
    left = find_depth_tool(tree,n,index)

    index[0] += 1
    right = find_depth_tool(tree,n,index)

    return (max(left, right) + 1)

def find_depth(tree, n) :

    index = [0]
    return find_depth_tool(tree,n,index)


tree= "nlnll"
n = len(tree)

print(find_depth(tree,n))
# Out:
# 2

# %% [markdown]
# ![Screenshot 2023-07-02 103306.png](data:image/png;base64,...)

# %%
class Node:

    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def left_view_tool(root, level, max_level):

    if root is None:
        return

    if (max_level[0] < level):
        print (root.data, end = " ")
        max_level[0] = level

    left_view_tool(root.left, level + 1, max_level)
    left_view_tool(root.right, level + 1, max_level)

def left_View(root):
    max_level = [0]
    left_view_tool(root, 1, max_level)



root = Node(4)
root.left = Node(5)
root.right = Node(2)
root.right.right = Node(1)
root.right.left = Node(3)
root.right.left.left = Node(6)
root.right.left.right = Node(7)

left_View(root)
# Out:
# 4 5 3 6

# %% [markdown]
# ![Screenshot 2023-07-02 103522.png](data:image/png;base64,...)

# %%
class Node:

    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def right_view_tool(root, level, max_level):

    if root is None:
        return

    if (max_level[0] < level):
        print (root.data, end = " ")
        max_level[0] = level

    right_view_tool(root.right, level + 1, max_level)
    right_view_tool(root.left, level + 1, max_level)

def right_View(root):
    max_level = [0]
    right_view_tool(root, 1, max_level)



root = Node(4)
root.left = Node(5)
root.right = Node(2)
root.right.right = Node(1)
root.right.left = Node(3)
root.right.left.left = Node(6)
root.right.left.right = Node(7)

right_View(root)
# Out:
# 4 2 1 7

# %% [markdown]
# ![Screenshot 2023-07-02 103657.png](data:image/png;base64,...)

# %%
class Node:

    def __init__(self, key = None, left = None, right = None):

        self.data = key
        self.left = left
        self.right = right

def print_bottomView(root):

    d = dict()

    print_bottomView_tool(root, d, 0, 0)

    for i in sorted(d.keys()):
        print(d[i][0], end = " ")

def print_bottomView_tool(root, d, hd, level):

    if root is None:
        return

    if hd in d:
        if level >= d[hd][1]:
            d[hd] = [root.data, level]
    else:
        d[hd] = [root.data, level]

    print_bottomView_tool(root.left, d, hd - 1,level + 1)

    print_bottomView_tool(root.right, d, hd + 1,level + 1)



root = Node(20)
root.left = Node(8)
root.right = Node(22)
root.left.left = Node(5)
root.left.right = Node(3)
root.right.left = Node(4)
root.right.right = Node(25)
root.left.right.left = Node(10)
root.left.right.right = Node(14)

print_bottomView(root)
# Out:
# 5 10 4 14 25
